# %%
import numpy as np
points = np.array([[1,1], [1,2], [1,3], [2,1], [2,2], [2,3], [3,1], [3,2], [3,3]])
p = np.array([2.5, 2])
import matplotlib.pyplot as plt
plt.plot(points[:,0], points[:,1], "ro")
plt.plot(p[0], p[1], "bo");

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 5, 10)
y = x**2
plt.plot(x, y);

# %%
x = np.linspace(0, 10, 20)
y = x**2.0
plt.plot(x, y, "bo-", linewidth=3, markersize=5);

# %%
plt.plot(x, y, "gs-", linewidth=1, markersize=3);

# %%
x = np.linspace(0, 10, 20)
y1 = x**2.0
y2 = x**1.5
plt.plot(x, y1, "bo-", linewidth=2, markersize=12, label="First")
plt.plot(x, y2, "gs-", linewidth=2, markersize=12, label="Second")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left")
plt.savefig("mplot.pdf")

# %%
x = np.logspace(-1, 1, 20)
y1 = x**2.0
y2 = x**1.5
plt.plot(x, y1, "bo-", linewidth=2, markersize=5, label="First")
plt.plot(x, y2, "gs-", linewidth=2, markersize=5, label="Second")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left")
plt.savefig("mplot.pdf")

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.standard_normal(size=1000)
plt.hist(x)
# Out:
# (array([  7.,  16.,  86., 120., 196., 236., 182., 102.,  43.,  12.]),
#  array([-2.99369079, -2.42225623, -1.85082167, -1.27938711, -0.70795255,
#         -0.13651799,  0.43491657,  1.00635113,  1.57778569,  2.14922026,
#          2.72065482]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x, density=True)
# Out:
# (array([0.01224987, 0.02799971, 0.15049842, 0.2099978 , 0.34299641,
#         0.41299567, 0.31849666, 0.17849813, 0.07524921, 0.02099978]),
#  array([-2.99369079, -2.42225623, -1.85082167, -1.27938711, -0.70795255,
#         -0.13651799,  0.43491657,  1.00635113,  1.57778569,  2.14922026,
#          2.72065482]),
#  <a list of 10 Patch objects>)

# %%
import matplotlib.pyplot as plt
import numpy as np
x =np.random.randn(1000)
plt.hist(x)
# Out:
# (array([  8.,  20., 106., 216., 272., 212., 123.,  32.,  10.,   1.]),
#  array([-3.2885464 , -2.57072356, -1.85290071, -1.13507787, -0.41725502,
#          0.30056783,  1.01839067,  1.73621352,  2.45403636,  3.17185921,
#          3.88968206]),
#  <a list of 10 Patch objects>)

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.rand(30)
y = np.random.rand(30)
colors = np.random.rand(30)
size = np.pi * (np.random.rand(30)*20) **2
plt.scatter(x, y, s=size, c = colors, marker='*', alpha=0.7)
plt.show()
