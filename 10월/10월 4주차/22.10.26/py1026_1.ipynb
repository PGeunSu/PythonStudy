# ...

# %%
f = open("C:\\Users\\KGA_17\\Desktop\\d1.csv",'r',encoding="cp949")
result = f.read()

result = result.split(",")
print(result[1])
# Out:
# 2021년10월_총인구수

# %%
#csv 모듈을 사용하여 불러오기
import csv
f = open("C:\\Users\\KGA_17\\Desktop\\d1.csv",'r',encoding="cp949")#
result = csv.reader(f)
# type : <class '_csv.reader'>

next(result)
next(result)

data = {}
for row in result:
    data[row[0]]=[]
    for i in range(1,len(row),6):
        data[row[0]].append(row[i])
print(data)
# Out:
# {'세종특별자치시  조치원읍(3611025000)': ['43,406', '43,413', '43,262', '43,210', '43,274', '43,191', '43,113', '43,007', '42,906', '42,819', '42,697', '42,622'], '세종특별자치시  연기면(3611031000)': ['2,792', '2,814', '2,812', '2,811', '2,804', '2,780', '2,750', '2,733', '2,719', '2,696', '2,684', '2,680'], '세종특별자치시  연동면(3611032000)': ['3,133', '3,132', '3,112', '3,113', '3,107', '3,086', '3,103', '3,092', '3,092', '3,078', '3,058', '3,039'], '세종특별자치시  부강면(3611033000)': ['6,211', '6,178', '6,152', '6,148', '6,110', '6,090', '6,088', '6,044', '6,038', '6,035', '6,007', '5,948'], '세종특별자치시  금남면(3611034000)': ['9,030', '9,028', '8,975', '8,980', '8,950', '8,917', '8,859', '8,772', '8,779', '8,778', '8,753', '8,708'], '세종특별자치시  장군면(3611035000)': ['7,021', '7,018', '6,994', '7,019', '7,026', '7,057', '7,045', '7,011', '7,020', '6,971', '6,951', '6,928'], '세종특별자치시  연서면(3611036000)': ['7,418', '7,400', '7,380', '7,330', '7,350', '7,336', '7,295', '7,306', '7,318', '7,314', '7,312', '7,300'], '세종특별자치시  전의면(3611
# ...

# %%
#csv 연도별 다운

# %%
#pandas로 불러오기
import pandas as pd
result = pd.read_csv("C:\\Users\\KGA_17\\Desktop\\d4.csv" , encoding="cp949")
print(result)
# Out:
#                             행정구역 2019년_총인구수 2019년_세대수  2019년_세대당 인구  \
# 0   세종특별자치시 세종특별자치시 (3611000000)    340,575   135,408          2.52
# 1      세종특별자치시  조치원읍(3611025000)     43,266    19,472          2.22
# 2       세종특별자치시  연기면(3611031000)      2,577     1,445          1.78
# 3       세종특별자치시  연동면(3611032000)      3,187     1,680          1.90
# 4       세종특별자치시  부강면(3611033000)      6,308     3,249          1.94
# 5       세종특별자치시  금남면(3611034000)      8,761     4,509          1.94
# 6       세종특별자치시  장군면(3611035000)      6,238     3,453          1.81
# 7       세종특별자치시  연서면(3611036000)      7,518     3,834          1.96
# 8       세종특별자치시  전의면(3611037000)      5,863     3,045          1.93
# 9       세종특별자치시  전동면(3611038000)      3,758     2,130          1.76
# 10      세종특별자치시  소정면(3611039000)      2,545     1,231          2.07
# 11      세종특별자치시  한솔동(3611051000)     19,287     6,333          3.05
# 12      세종특별자치시  새롬동(3611051500)     53,482    20,495          2.61
# ...

# %%
print(result.columns)
# Out:
# Index(['행정구역', '2019년_총인구수', '2019년_세대수', '2019년_세대당 인구', '2019년_남자 인구수',
#        '2019년_여자 인구수', '2019년_남여 비율', '2020년_총인구수', '2020년_세대수',
#        '2020년_세대당 인구', '2020년_남자 인구수', '2020년_여자 인구수', '2020년_남여 비율',
#        '2021년_총인구수', '2021년_세대수', '2021년_세대당 인구', '2021년_남자 인구수',
#        '2021년_여자 인구수', '2021년_남여 비율'],
#       dtype='object')

# %%
print(result.iloc[1,0])
print(result.iloc[2,0])
# Out:
# 세종특별자치시  조치원읍(3611025000)
# 세종특별자치시  연기면(3611031000)

# %%
#연도별 행정구역 거주지 인구 가져오기
#pandas모듈로 불러온 데이터는 DataFrame 자료형으로,
#DataFrame 내 함수를 활용하여 쉽게 가져올 수 있다.
#columns : 칼럼의 목록을 가져올 수 있음
#iloc : 행 번호로 값을 선택할 수 있음 -> 연도볋 행정구역별 거주지인구를 가져올 수 있음.

# %%
s = "2020년_여자 인구수"
s.endswith("인구수")
# Out:
# True

# %%
print(result.iloc[1,0])
print(result.iloc[1, range(1,len(result.columns),6)])
# Out:
# 세종특별자치시  조치원읍(3611025000)
# 2019년_총인구수    43,266
# 2020년_총인구수    43,100
# 2021년_총인구수    43,262
# Name: 1, dtype: object

# %%
import pandas as pd
result = pd.read_csv("C:\\Users\\KGA_17\\Desktop\\d4.csv" , encoding="cp949")
data={}
for i in range(1, len(result)):
    data[result.iloc[i,0]] = result.iloc[1, range(1, len(result.columns),6)]
print(data)
# Out:
# {'세종특별자치시  조치원읍(3611025000)': 2019년_총인구수    43,266
# 2020년_총인구수    43,100
# 2021년_총인구수    43,262
# Name: 1, dtype: object, '세종특별자치시  연기면(3611031000)': 2019년_총인구수    43,266
# 2020년_총인구수    43,100
# 2021년_총인구수    43,262
# Name: 1, dtype: object, '세종특별자치시  연동면(3611032000)': 2019년_총인구수    43,266
# 2020년_총인구수    43,100
# 2021년_총인구수    43,262
# Name: 1, dtype: object, '세종특별자치시  부강면(3611033000)': 2019년_총인구수    43,266
# 2020년_총인구수    43,100
# 2021년_총인구수    43,262
# Name: 1, dtype: object, '세종특별자치시  금남면(3611034000)': 2019년_총인구수    43,266
# 2020년_총인구수    43,100
# 2021년_총인구수    43,262
# Name: 1, dtype: object, '세종특별자치시  장군면(3611035000)': 2019년_총인구수    43,266
# 2020년_총인구수    43,100
# 2021년_총인구수    43,262
# Name: 1, dtype: object, '세종특별자치시  연서면(3611036000)': 2019년_총인구수    43,266
# 2020년_총인구수    43,100
# 2021년_총인구수    43,262
# Name: 1, dtype: object, '세종특별자치시  전의면(3611037000)': 2019년_총인구수    43,266
# 2020년_총인구수    43,100
# 2021년_총인구수    43,262
# ...

# %%
import pandas as pd
result = pd.read_csv("C:\\Users\\KGA_17\\Desktop\\d5.csv" , encoding="cp949")
print(result)
# Out:
#                             행정구역 2019년_계_총인구수 2019년_계_연령구간인구수 2019년_계_0~9세  \
# 0   세종특별자치시 세종특별자치시 (3611000000)      340,575         340,575       47,249
# 1      세종특별자치시  조치원읍(3611025000)       43,266          43,266        3,521
# 2       세종특별자치시  연기면(3611031000)        2,577           2,577           78
# 3       세종특별자치시  연동면(3611032000)        3,187           3,187          107
# 4       세종특별자치시  부강면(3611033000)        6,308           6,308          384
# 5       세종특별자치시  금남면(3611034000)        8,761           8,761          326
# 6       세종특별자치시  장군면(3611035000)        6,238           6,238          211
# 7       세종특별자치시  연서면(3611036000)        7,518           7,518          387
# 8       세종특별자치시  전의면(3611037000)        5,863           5,863          229
# 9       세종특별자치시  전동면(3611038000)        3,758           3,758           97
# 10      세종특별자치시  소정면(3611039000)        2,545           2,545          126
# ...

# %%
import pandas as pd
result = pd.read_csv("C:\\Users\\KGA_17\\Desktop\\d5.csv" , encoding="cp949")
for i in range(1,len(result)):
    print(result.iloc[i,0])
    for j in range(len(result.columns)):
        if result.columns[j].endswith("년_거주자_30~39세"):
            print(result.columns[j],result.iloc[i,j])
    print()
# Out:
# 세종특별자치시  조치원읍(3611025000)
# 2019년_거주자_30~39세 5,506
# 2020년_거주자_30~39세 5,406
# 2021년_거주자_30~39세 5,367
#
# 세종특별자치시  연기면(3611031000)
# 2019년_거주자_30~39세 288
# 2020년_거주자_30~39세 334
# 2021년_거주자_30~39세 375
#
# 세종특별자치시  연동면(3611032000)
# 2019년_거주자_30~39세 274
# 2020년_거주자_30~39세 275
# 2021년_거주자_30~39세 295
#
# 세종특별자치시  부강면(3611033000)
# 2019년_거주자_30~39세 683
# 2020년_거주자_30~39세 722
# 2021년_거주자_30~39세 725
#
# 세종특별자치시  금남면(3611034000)
# 2019년_거주자_30~39세 833
# 2020년_거주자_30~39세 881
# 2021년_거주자_30~39세 930
#
# 세종특별자치시  장군면(3611035000)
# 2019년_거주자_30~39세 754
# 2020년_거주자_30~39세 841
# 2021년_거주자_30~39세 945
#
# 세종특별자치시  연서면(3611036000)
# 2019년_거주자_30~39세 742
# 2020년_거주자_30~39세 721
# 2021년_거주자_30~39세 708
#
# 세종특별자치시  전의면(3611037000)
# 2019년_거주자_30~39세 519
# 2020년_거주자_30~39세 514
# 2021년_거주자_30~39세 463
#
# 세종특별자치시  전동면(3611038000)
# 2019년_거주자_30~39세 275
# 2020년_거주자_30~39세 256
# 2021년_거주자_30~39세 224
#
# 세종특별자치시  소정면(3611039000)
# 2019년_거주자_30~39세 202
# 2020년_거주자_30~39세 183
# 2021년_거주자_30~39세 181
#
# ...

# %%
print(result.iloc[1:,6])
# Out:
# 1      5,506
# 2        288
# 3        274
# 4        683
# 5        833
# 6        754
# 7        742
# 8        519
# 9        275
# 10       202
# 11     2,744
# 12    12,260
# 13     5,847
# 14         0
# 15     3,717
# 16     5,950
# 17     6,978
# 18     7,385
# 19         0
# 20     3,944
# 21     2,395
# 22         0
# Name: 2019년_거주자_30~39세, dtype: object

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y = [2,3,4,5]
plt.plot(x,y)
plt.show()

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

figure = plt.figure()
axes = figure.add_subplot(111)

x=[1,2,3,4]
y=[2,3,4,5]

x2= np.array([1,2,3,4])
y2= np.array([4,1,3,6])

axes.plot(x,y, color="red",linestyle="dashed", marker="^")
axes.plot(x2,y2, color="k", linestyle="dotted",marker="o")
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot(111)
axes2 = axes.twinx() #x축은 공유하고 y축은 따로 씀

x=[1,2,3,4]
y=[2,3,4,5]
x2 = [1,2,3,4]
y2 = [4,6,1,9]

axes.bar(x,y, color="green",label="bar")
axes2.plot(x2,y2, color="k", label="plot")

axes.legend()
axes2.legend(loc=1)
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot(111)

label = ["a","b","c","d"]
data = [1,1,2,3]

axes.pie(data,labels = label)
plt.show()
