# %%
import csv
f=open("movies.csv","r",encoding="utf-8")
data = csv.reader(f)
next(data)
result = []

for i in data :
    result.extend(i[2].split('l')) #split 함수를 활용하여 'l'을 기준으로 데이터 분리 및 저장
print(len(result)) # 전체 영화의 총 장르 개수
print(result)
# Out:
# 14649
# ...
