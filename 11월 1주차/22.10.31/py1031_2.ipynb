# %%
import matplotlib.pyplot as plt

x = [1,2,3]
y = [2,4,8]
plt.plot(x,y)

# %%
print(plt.plot(x,y))

# %%
plt.plot(x,y)
plt.title("꺾은선 그래프")
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
# /Users/rls_su/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/rls_su/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/rls_su/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/rls_su/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import matplotlib
matplotlib.rcParam["font.family"] = "Malgun Gothic"
matplotlib.rcParam["font.size"] = 15 # 글자크기
matplotlib.rcParam["axes.unicode_minus"] = False # 한글 폰트 사용시, 마이너스 글자가 깨지는 현상 해결
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/x8/36bf6t7d46dbzngss_dsh51r0000gn/T/ipykernel_1584/2199051929.py in <module>
#       1 import matplotlib
# ----> 2 matplotlib.rcParam["font.family"] = "Noto Sans Osage"
#       3 matplotlib.rcParam["font.size"] = 15 # 글자크기
#       4 matplotlib.rcParam["axes.unicode_minus"] = False # 한글 폰트 사용시, 마이너스 글자가 깨지는 현상 해결
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/__init__.py in __getattr__(name)
#     220         if name in props:
#     221             return props[name].__get__(instance)
# --> 222         raise AttributeError(
#     223             f"module {cls.__module__!r} has no attribute {name!r}")
#     224
#
# AttributeError: module 'matplotlib' has no attribute 'rcParam'

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist #사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['STIXSizeOneSym',
#  'DejaVu Sans',
#  'cmss10',
#  'DejaVu Sans Display',
#  'DejaVu Sans',
#  'STIXSizeFourSym',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'DejaVu Serif Display',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'cmr10',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'cmmi10',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'cmsy10',
#  'cmb10',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'cmtt10',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'cmex10',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'STIXSizeFiveSym',
#  'DejaVu Serif',
#  'Noto Sans Tagbanwa',
#  'Impact',
#  'STIX Two Math',
#  'Noto Sans Saurashtra',
#  'Noto Sans Modi',
#  'Avenir Next',
#  'Noto Sans Mro',
#  'STIXIntegralsUp',
#  'Noto Serif Myanmar',
#  'Hiragino Sans',
#  'Comic Sans MS',
#  'Optima',
#  'Al Tarikh',
# ...
