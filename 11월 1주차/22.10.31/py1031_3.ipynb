# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
x = [1,2,3]
y = [2,4,8]

plt.plot(x, y)
plt.title('꺾은선 그래프', fontdict={'family':'AppleGothic', 'size':20}) # 개별 폰트 설정
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot(x,y)
plt.xlabel('x축')
plt.ylabel("y축")
# Out:
# Text(0, 0.5, 'y축')

# %%
plt.plot(x,y)
plt.xlabel("x축", color="red", loc="right")#left, center,right
plt.ylabel("y축", color="#00aa00", loc="top")#top, center, bottom
# Out:
# Text(0, 1, 'y축')

# %%
plt.plot(x,y, label="무슨데이터")
plt.legend()

# %%
plt.plot(x,y, label="무슨데이터")
plt.legend(loc="lower right")

# %%
plt.plot(x,y ,label="범례")
plt.legend(loc=(0.1, 0.1)) #x축 y축 (0~1 사이)

# %%
plt.plot(x,y, linewidth=5) # 선두께

# %%
plt.plot(x,y, marker="o")

# %%
plt.plot(x,y, marker="v", markersize = 10)

# %%
plt.plot(x,y ,linestyle=":")

# %%
plt.plot(x,y ,linestyle="--")

# %%
plt.plot(x,y ,linestyle="-.")

# %%
plt.plot(x,y,color='blue')

# %%
plt.plot(x,y, "ro--") #color - red , marker : o ,linestyle:--

# %%
plt.plot(x,y, marker="o",mfc="red",ms=10,mec="blue",ls=":")

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.savefig("graph.png",dpi=100)

# %%
plt.plot(x,y ,marker="o")

for idx, txt in enumerate(y):
    plt.text(x[idx], y[idx] + 0.3, txt, ha = "center", color="blue")

# %%
#covid-19 백신 종류별 접종 인구
days = [1,2,3]# 1일, 2일 ,3일
az = [2,4,8] #단위 : 만명 , 1일부터 3일까지 아스트라제네카 접종인구
prizer = [5,1,3] #화이자
morderna = [1,2,5] #모더나

plt.plot(days, az)
plt.plot(days, prizer)
plt.plot(days, morderna)

# %%
plt.plot(days, az, label="az")
plt.plot(days, prizer, label="pfizer",marker="o", linestyle="--")
plt.plot(days, morderna, label="morderna", marker="s" , ls="-.")

plt.legend()

# %%
plt.plot(days, az, label="az")
plt.plot(days, prizer, label="pfizer",marker="o", linestyle="--")
plt.plot(days, morderna, label="morderna", marker="s" , ls="-.")

plt.legend(ncol=3)

# %%
labels = ["강백호","서태웅","정대만"]
values = [190,187,184]

plt.bar(labels, values)
# Out:
# <BarContainer object of 3 artists>

# %%
colors = ['r','g','b']
plt.bar(labels, values, color= colors, alpha=0.5) #alpha : 불투명도
# Out:
# <BarContainer object of 3 artists>

# %%
ticks=["1학생","2학생","3학생"]
plt.bar(labels, values)
plt.xticks(labels, ticks, rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x7fa2d43c02e0>,
#   <matplotlib.axis.XTick at 0x7fa2d43c02b0>,
#   <matplotlib.axis.XTick at 0x7fa2d43bae80>],
#  [Text(0.0, 0, '1학생'), Text(1.0, 0, '2학생'), Text(2.0, 0, '3학생')])

# %%
plt.barh(labels,values)
plt.xlim(175,195) #시작과 끝의 눈금 위치를 변경
# Out:
# (175.0, 195.0)

# %%
bar = plt.bar(labels, values)
bar[0].set_hatch('/') # ////
bar[1].set_hatch('x') # xxxx
bar[2].set_hatch('..') # ...

# %%
bar = plt.bar(labels, values)
plt.ylim(175,195)

for idx, rect in enumerate(bar):
    plt.text(idx, rect.get_height() + 0.5, values[idx], ha="center", color="blue")

# %%
import pandas as pd
df = pd.read_excel("score.xlsx")
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
plt.plot(df["지원번호"],df["영어"])
plt.plot(df["지원번호"],df["수학"])

# %%
plt.plot(df["지원번호"],df["영어"])
plt.plot(df["지원번호"],df["수학"])

plt.grid(axis="y", color="purple", alpha=0.5, linestyle="--", linewidth=2)

# %%
plt.bar(df["이름"],df["국어"])
plt.bar(df["이름"],df["영어"])
# Out:
# <BarContainer object of 8 artists>

# %%
plt.bar(df["이름"],df["국어"])
plt.bar(df["이름"],df["영어"], bottom = df["국어"])
# Out:
# <BarContainer object of 8 artists>

# %%
plt.bar(df["이름"],df["국어"])
plt.bar(df["이름"],df["영어"], bottom = df["국어"])
plt.bar(df["이름"],df["수학"], bottom = df["국어"]+df["영어"])
# Out:
# <BarContainer object of 8 artists>

# %%
plt.bar(df["이름"],df["국어"],label="국어")
plt.bar(df["이름"],df["영어"],label="영어", bottom = df["국어"])
plt.bar(df["이름"],df["수학"],label="수학", bottom = df["국어"]+df["영어"])

plt.xticks(rotation=60)
plt.legend()

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']


plt.pie(values, labels = labels, autopct = "%.1f%%",startangle=90, counterclock=False)
plt.show()

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']
explode = [0.05] * 6


plt.pie(values, labels = labels, explode = explode)
plt.show()

# %%
plt.pie(values, labels = labels, explode = explode)
plt.legend(loc=(1.2, 0.3))
plt.show()

# %%
plt.pie(values, labels = labels, explode = explode)
plt.legend(loc=(1.2, 0.3), title="언어별 선호도")
plt.show()

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']
# colors = ['b', 'g', 'r', 'c', 'm', 'y']
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
explode = [0.05] * 6

plt.pie(values, labels=labels, startangle=90, counterclock=False, colors=colors, explode=explode)
plt.show()

# %%
wedgeprops={"width":0.6}

plt.pie(values, labels=labels, startangle=90, counterclock=False, colors=colors, explode=explode, wedgeprops = wedgeprops)
plt.show()

# %%
wedgeprops={"width":0.6, "edgecolor":"w", "linewidth":2}

plt.pie(values, labels=labels, startangle=90, counterclock=False, colors=colors, explode=explode, wedgeprops = wedgeprops)
plt.show()

# %%
def custom_autopct(pct):
    # return ('%.1f%%' % pct) if pct >= 10 else ''
    # return '{:.1f}%'.format(pct) if pct >= 10 else ''
    return '{:.0f}%'.format(pct) if pct >= 10 else ''

plt.pie(values, labels=labels, autopct=custom_autopct, startangle=90, counterclock=False, colors=colors, wedgeprops=wedgeprops, pctdistance=0.7)
plt.show()

# %%
df["학년"]=[3,3,2,1,1,3,2,2]
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기  학년
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python   3
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java   3
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript   2
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN   1
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN   1
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C   3
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON   2
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#   2

# %%
plt.scatter(df["영어"],df["수학"] )
plt.xlabel("영어 점수")
plt.ylabel("수학 점수")
# Out:
# Text(0, 0.5, '수학 점수')

# %%
import numpy as np
sizes = np.random.rand(8) * 1000
sizes
# Out:
# array([521.97651639, 337.52096207, 716.20093022, 931.34182758,
#        959.11107547, 937.69114772,  50.32304149, 752.73053291])

# %%
plt.figure(figsize=(7,7))
plt.scatter(df["영어"],df["수학"], s = sizes, c=df["학년"], cmap="viridis", alpha=0.3)
plt.xlabel("영어 점수")
plt.ylabel("수학 점수")
plt.colorbar(ticks=[1,2,3], label="학년", shrink =0.5, orientation="horizontal")
