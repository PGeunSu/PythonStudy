# %%
import pandas as pd
file_name = "202108_202108_연령별인구현황_월간.xlsx"
df_w = pd.read_excel(file_name, skiprows=3, index_col ="행정기관", usecols="B,AB:AV")
df_w
# Out:
# /Users/rls_su/opt/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국         765,718  1,099,511  1,146,252  1,142,146  1,521,873  1,672,118
# 서울특별시      122,200    168,049    179,786    192,489    322,918    422,032
# 부산광역시       44,214     64,756     64,561     64,967     96,558    105,853
# 대구광역시       33,301     50,145     51,747     53,488     72,843     73,837
# 인천광역시       43,971     63,283     66,430     65,516     86,994    101,318
# 광주광역시       22,602     33,687     36,409     37,671     50,079     49,107
# 대전광역시       21,700     31,506     33,996     35,270     49,378     50,621
# 울산광역시       18,529     27,124     27,162     25,248     29,711     31,220
# ...

# %%
import pandas as pd
file_name = "202108_202108_연령별인구현황_월간.xlsx"
df_m = pd.read_excel(file_name, skiprows=3, index_col ="행정기관", usecols="B,E:Y")
df_m
# Out:
# /Users/rls_su/opt/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국         807,150  1,154,806  1,215,483  1,229,848  1,652,371  1,875,014
# 서울특별시      129,766    176,433    189,993    201,088    292,214    402,129
# 부산광역시       46,491     68,329     68,191     69,493    102,324    116,387
# 대구광역시       35,211     52,460     55,208     59,593     81,333     86,007
# 인천광역시       46,559     66,423     70,227     69,398     93,223    111,721
# 광주광역시       23,616     35,604     38,895     40,649     54,299     53,982
# 대전광역시       22,905     33,431     36,058     38,060     52,167     58,241
# 울산광역시       19,422     28,833     29,486     28,511     37,810     41,142
# ...

# %%
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns
# Out:
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
df_w.columns = df_m.columns #컬럼명 통일
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.iloc[0] = df_w.iloc[0].str.replace(",","").astype(int) #1,195,1951 => 119051951 (정수형)
df_w
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국          765718  1099511  1146252  1142146  1521873  1672118  1523976
# 서울특별시      122,200  168,049  179,786  192,489  322,918  422,032  365,483
# 부산광역시       44,214   64,756   64,561   64,967   96,558  105,853   93,317
# 대구광역시       33,301   50,145   51,747   53,488   72,843   73,837   62,613
# 인천광역시       43,971   63,283   66,430   65,516   86,994  101,318   90,591
# 광주광역시       22,602   33,687   36,409   37,671   50,079   49,107   40,131
# 대전광역시       21,700   31,506   33,996   35,270   49,378   50,621   42,816
# 울산광역시       18,529   27,124   27,162   25,248   29,711   31,220   30,500
# 세종특별자치시      9,941   13,034   12,604    9,535    8,242   10,397   13,568
# 경기도        225,076  319,632  327,337  317,509  407,961  448,234  423,626
# 강원도         21,125   28,786   31,597   33,185   40,061   37,118   34,911
# 충청북도        24,103   34,144   35,652   35,008   43,448   43,605   40,542
# ...

# %%
df_m.iloc[0] = df_m.iloc[0].str.replace(",","").astype(int) #1,195,1951 => 119051951 (정수형)
df_m
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국          807150  1154806  1215483  1229848  1652371  1875014  1655155
# 서울특별시      129,766  176,433  189,993  201,088  292,214  402,129  364,322
# 부산광역시       46,491   68,329   68,191   69,493  102,324  116,387   99,345
# 대구광역시       35,211   52,460   55,208   59,593   81,333   86,007   72,838
# 인천광역시       46,559   66,423   70,227   69,398   93,223  111,721   98,422
# 광주광역시       23,616   35,604   38,895   40,649   54,299   53,982   42,930
# 대전광역시       22,905   33,431   36,058   38,060   52,167   58,241   49,117
# 울산광역시       19,422   28,833   29,486   28,511   37,810   41,142   36,732
# 세종특별자치시     10,196   13,780   12,849    9,575    9,082   10,464   12,925
# 경기도        236,894  334,127  344,189  338,011  442,302  510,737  460,632
# 강원도         22,143   30,286   33,725   36,191   50,466   48,858   40,577
# 충청북도        25,422   35,376   38,000   38,412   51,297   57,808   48,449
# ...

# %%
#데이터 시각화
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams["font.family"] = "AppleGothic"
matplotlib.rcParams["font.size"] = 15 # 글자크기
matplotlib.rcParams["axes.unicode_minus"] = False #한글 폰트 사용 시 마이너스 글저가 꺠지는 현상을 해결

# %%
plt.figure(figsize=(10,7))
plt.barh(df_m.columns, -df_m.iloc[0] // 1000) #단위 천명
plt.barh(df_w.columns, df_w.iloc[0] // 1000)
plt.title("2021대한민국 인구 피라미드")
plt.savefig("2021_인구피라미드.png", dpi=100)
plt.show()

# %%
#출생아 수 및 합계 출산율
import pandas as pd
df = pd.read_excel("stat_142801.xls", skiprows=2, nrows=2, index_col=0) #nrwos = 몇 행을 보여줄 것인가
df
# Out:
#            2011     2012     2013     2014     2015     2016     2017  \
# 출생아 수   471.300  484.600  436.500  435.400  438.400  406.200  357.800
# 합계 출산율    1.244    1.297    1.187    1.205    1.239    1.172    1.052
#
#            2018     2019    2020
# 출생아 수   326.800  302.700  272.30
# 합계 출산율    0.977    0.918    0.84

# %%
df.index.values
# Out:
# array(['출생아\xa0수', '합계\xa0출산율'], dtype=object)

# %%
df.rename(index={'출생아\xa0수':"출생아 수",'합계\xa0출산율':"합계 출산율"},inplace=True)
df
# Out:
#            2011     2012     2013     2014     2015     2016     2017  \
# 출생아 수   471.300  484.600  436.500  435.400  438.400  406.200  357.800
# 합계 출산율    1.244    1.297    1.187    1.205    1.239    1.172    1.052
#
#            2018     2019    2020
# 출생아 수   326.800  302.700  272.30
# 합계 출산율    0.977    0.918    0.84

# %%
df = df.T
df
# Out:
#       출생아 수  합계 출산율
# 2011  471.3   1.244
# 2012  484.6   1.297
# 2013  436.5   1.187
# 2014  435.4   1.205
# 2015  438.4   1.239
# 2016  406.2   1.172
# 2017  357.8   1.052
# 2018  326.8   0.977
# 2019  302.7   0.918
# 2020  272.3   0.840

# %%
plt.plot(df.index, df["출생아 수"])

# %%
plt.plot(df.index, df["출생아 수"])
plt.plot(df.index, df["합계 출산율"])

# %%
#이중축 꺾은선 그리기
fig, ax1 = plt.subplots(figsize=(10,7))
ax1.plot(df.index, df["출생아 수"], color="#ff812d")    

ax2 = ax1.twinx() #x축을 공유하는 쌍둥이 axis
ax2.plot(df.index, df["합계 출산율"], color="blue")

# %%
fig, ax1 = plt.subplots(figsize=(13,5))
ax1.set_ylabel("출생아 수 (천 명)")
ax1.set_ylim(250,700)
ax1.set_yticks([300,400,500,600])
ax1.bar(df.index, df["출생아 수"], color="#ff812d")

ax2 = ax1.twinx()
ax2.set_ylabel("합계 출산율(기임여성 1명당 명)")
ax2.set_ylim(0, 1.5)
ax2.set_yticks([0,1])
ax2.plot(df.index, df["합계 출산율"], color="#ffd100")
